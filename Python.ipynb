# %%
#Day1
""" 
Hello  
Python 
"""

# %%
print("hello")
print("------------")
print('python')
print("------------")
print("ABC@hello \" this is python line \" ")
print("------------")
print("ABC@hello \' this is python line \' ")
print("------------")
print("ABC@hello \n this is python line  ")
print("------------")
print("ABC@hello \\ this is python line \\ ")
print("------------")
print("\t this is a tab")
print("------------")
print(""" 
this is a multiline
statement that i am 
trying to print
""")
# Out:
# hello
# ------------
# python
# ------------
# ABC@hello " this is python line "
# ------------
# ABC@hello ' this is python line '
# ------------
# ABC@hello
#  this is python line
# ------------
# ABC@hello \ this is python line \
# ------------
# 	 this is a tab
# ------------
#
# this is a multiline
# statement that i am
# trying to print
