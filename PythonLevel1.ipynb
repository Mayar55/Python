# %%
#Day1
""" 
Hello  
Python 
"""

# %%
print("hello")
print("------------")
print('python')
print("------------")
print("ABC@hello \" this is python line \" ")
print("------------")
print("ABC@hello \' this is python line \' ")
print("------------")
print("ABC@hello \n this is python line  ")
print("------------")
print("ABC@hello \\ this is python line \\ ")
print("------------")
print("\t this is a tab")
print("------------")
print(""" 
this is a multiline
statement that i am 
trying to print
""")
# Out:
# hello
# ------------
# python
# ------------
# ABC@hello " this is python line "
# ------------
# ABC@hello ' this is python line '
# ------------
# ABC@hello
#  this is python line
# ------------
# ABC@hello \ this is python line \
# ------------
# 	 this is a tab
# ------------
#
# this is a multiline
# statement that i am
# trying to print

# %%
#variables

x =  "Mayar"
print(x,"is a good student")
# Out:
# Mayar is a good student

# %%
#input : get from the user 
name = input("enter ur name : ")
print("my name is" , name)
# Out:
# my name is mayar

# %%
#Python automatically detect the data type 
#50.upper() : throw error
"hello".upper()
#null , single value (int , str , bool , float) , multi values (list , set , tuple , etc..)
str_v1 = 'hello' ,
str_v2 = "hi" ,
str_blank = "",
none_v = None,
boolean_v1 = True ,
boolean_v2 = False

# %%
#functions(user defined , standard , 3rd party [pandas,tensorFlow,etc])
#standard functions(built-in , math(imported) , )
#function(independent block of code),method(function belong to a class)

text = "hello"
no = 12

print(type(text))
print(type(no))
print(len(text))
print(no.bit_length())
# Out:
# <class 'str'>
# <class 'int'>
# 5
# 4

# %%
#string functions 

name = "mayar"
type(name)
str(5)

#cannot combine (int) with (str) using (+) 

len(name) #count space
name.count("mayar") #how often a word appear , case sensitive

#transformation
price = "123,45$"
price.replace(",",".").replace("$","") #(old,new)

n1 = "python" 
n2="lang"
n3 = n1+n2
print(n3) #no space between 
print(n1+" "+n2)

#f-string : f for formatting
no = 20
name = "mayar"
print(f"my name is {name} , i am {no} years old")
print(f"4 + 6 = {4 + 6}")

#split

stamp = "mayar-20"
stamp.split("-") # values split in list 

"ha" * 3 #repeat

#pos indexing : 0 -> 
#neg indexing : -1 -> 
x = "hello" 
x[0] == x[-5] 
x[0:2]
x[-5:-3]
x[1:] #start included 
x[:3] #end not included 
x[1:5:2] #start included , end not included



#clean spaces

txt = " Engineer "
text = "##Engineer##"
txt.lstrip() # left
txt.rstrip() #right
txt.strip() #r & l spaces not in-between
text.strip("#") 
print("-------------------")

#search 

date1 = "2026-Feb-12"
print(date1.startswith("2026"))
date2 = "20-Feb-2026"
print(date2.endswith("2026"))
email = "mayar@gmail.com"
print("@" in email)
print(email.find("@"))


#validate
con = "USA"
phone1 = "23456"
phone2 = "23456e"
con.isalpha()
phone1.isnumeric()
phone2.isnumeric()
# Out:
# pythonlang
# python lang
# my name is mayar , i am 20 years old
# 4 + 6 = 10
# -------------------
# True
# True
# True
# 5
# False
